# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
type_color_palette = {"FIA": "#BF40BF",  
"MIA 1":"#7a469c", "MIA 2":"#548c9f", "MIA 3":"#8370a3",
"MIA 4":"#201e5a", "MIA 5":"#0077b6", "MIA 6":"#02b4d7",
"MIA 7": '#A5CF5A', "MIA 8": '#78B443', "MIA 9": '#405E2C', "MIA 10": '#61BC51', "MIA 11":'#4F794F', "MIA 12":'#3CB54A', "MIA 13":'#77C485', "MIA 14":'#19A049', "MIA 15":'#16724B', "MIA 16":'#0A7A3E', "MIA 17":'#30A779', "LIA 1":'#5AC099', "LIA 2":'#256451', 
"MIA 18": '#FCC013', "LIA 3": '#FAC610', "LIA 5":'#AF9731',"LIA 7":'#CEB82C',  "LIA 8":'#FADC00', "LIA 9":'#FBEF5F', "LIA 10":'#ACA769', "MIA 19":'#FCEE0D', "LIA 11":'#AEAD4D', "LIA 12":'#E8E749', "LIA 14":'#EFCB84', 
"LIA 4": '#D27D29', "LIA 6":'orange', "LIA 13":'#E56C25', "LIA 15":'#EB9761', 'LIA 16': '#E15D26',
"CTE I": '#D30000', "CTE II": '#E62465', "MIA 20":'#A81F23',
"TBD": "pink", "Unsolved": (0.7, 0.7, 0.7)}

CTE_colors = type_color_palette.values()

color_list = CTE_colors
# Calculate the number of rows and columns for subplots
num_colors = len(color_list)
num_rows = int(np.ceil(num_colors/10.0))

# Create subplots for each color
fig, axs = plt.subplots(num_rows, 10, figsize=(30, 3*num_rows))

# Flatten the axs array if it has multiple dimensions
if isinstance(axs, np.ndarray):
    axs = axs.flatten()

# Iterate over the color list and display each color in a subplot
for i, hex_code in enumerate(color_list):
    ax = axs[i]
    ax.set_facecolor(hex_code)
    ax.set_xticks([])
    ax.set_yticks([])
    
# Remove empty subplots if necessary
if num_colors < len(axs):
    for j in range(num_colors, len(axs)):
        axs[j].axis('off')
        
# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.1, wspace=0.1)
